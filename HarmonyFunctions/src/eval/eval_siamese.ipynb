# %%
import numpy as np
import pandas as pd
import plotly.express as px

# %%
df = pd.DataFrame({
    'h_predicted': np.load('../../data/siamese/h_predicted.npy'),
    'h_test': np.load('../../data/siamese/h_test.npy')
})

c1_test = np.load('../../data/siamese/c1_test.npy')
c2_test = np.load('../../data/siamese/c2_test.npy')

# %%
fig = px.scatter(df, 'h_predicted', 'h_test', opacity=0.05
)
fig.update_traces(marker={'size':5})
fig.show()
